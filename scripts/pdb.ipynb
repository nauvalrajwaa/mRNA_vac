# %%
files = [
    (
        "/Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR4/model.000.11_NS5_TLR4.pdb",
        "/Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR4/model.000.11_NS5_TLR4_fixed.pdb"
    ),
    (
        "/Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR4/model.000.20_NS5_TLR4.pdb",
        "/Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR4/model.000.20_NS5_TLR4_fixed.pdb"
    ),
    (
        "/Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR2/model.000.19_NS5_TLR2.pdb",
        "/Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR2/model.000.19_NS5_TLR2_fixed.pdb"
    ),
    (
        "/Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR2/model.000.20_NS5_TLR2.pdb",
        "/Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR2/model.000.20_NS5_TLR2_fixed.pdb"
    ),
    (
        "/Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR2/model.000.23_NS5_TLR2.pdb",
        "/Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR2/model.000.23_NS5_TLR2_fixed.pdb"
    )
    # (
    #     "/Users/user/Downloads/I-TASSER_MultiepitopeVacc/Cluspro/NS3_TLR2/model.000.11_NS3_TLR2.pdb",
    #     "/Users/user/Downloads/I-TASSER_MultiepitopeVacc/Cluspro/NS3_TLR2/model.000.11_NS3_TLR2_fixed.pdb"
    # ),
    # (
    #     "/Users/user/Downloads/I-TASSER_MultiepitopeVacc/Cluspro/NS4B_TLR2/model.000.17_NS4B_TLR2.pdb",
    #     "/Users/user/Downloads/I-TASSER_MultiepitopeVacc/Cluspro/NS4B_TLR2/model.000.17_NS4B_TLR2_fixed.pdb"
    # ),
    # (
    #     "/Users/user/Downloads/I-TASSER_MultiepitopeVacc/Cluspro/NS4B_TLR2/model.000.25_NS4B_TLR2.pdb",
    #     "/Users/user/Downloads/I-TASSER_MultiepitopeVacc/Cluspro/NS4B_TLR2/model.000.25_NS4B_TLR2_fixed.pdb"
    # ),
]

for input_file, output_file in files:
    inside_ligand = False
    with open(input_file, "r") as fin, open(output_file, "w") as fout:
        for line in fin:
            # deteksi blok ligand
            if line.startswith("HEADER lig."):
                inside_ligand = True
                fout.write(line)
                continue

            if line.startswith("HEADER") and not line.startswith("HEADER lig.000.02.pdb"):
                inside_ligand = False
                fout.write(line)
                continue

            # ubah chain A -> E hanya di blok ligand
            if inside_ligand and line.startswith(("ATOM", "HETATM")):
                line = line[:21] + "E" + line[22:]

            fout.write(line)

    print(f"✅ Selesai: {output_file}")
# Out:
# ✅ Selesai: /Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR4/model.000.11_NS5_TLR4_fixed.pdb
# ✅ Selesai: /Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR4/model.000.20_NS5_TLR4_fixed.pdb
# ✅ Selesai: /Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR2/model.000.19_NS5_TLR2_fixed.pdb
# ✅ Selesai: /Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR2/model.000.20_NS5_TLR2_fixed.pdb
# ✅ Selesai: /Users/user/Downloads/mRNA_Vaccine/Cluspro/NS5_TLR2/model.000.23_NS5_TLR2_fixed.pdb
